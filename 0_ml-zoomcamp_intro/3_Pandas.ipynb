# %% [markdown]
# # Introduction to Pandas
#
# Outline:
# - Data Frames
# - Series
# - Index
# - Accessing elements
# - Element-wise operations
# - Filtering
# - String operations
# - Summarizing operations
# - Missing values
# - Grouping
# - Getting the NumPy arrays

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## DataFrames
#
# A DataFrame represents a table in pandas and each table constitutes of many series

# %%
data = [
    ['Nissan', 'Stanza', 1991, 138, 4, 'MANUAL', 'sedan', 2000],
    ['Hyundai', 'Sonata', 2017, None, 4, 'AUTOMATIC', 'Sedan', 27150],
    ['Lotus', 'Elise', 2010, 218, 4, 'MANUAL', 'convertible', 54990],
    ['GMC', 'Acadia',  2017, 194, 4, 'AUTOMATIC', '4dr SUV', 34450],
    ['Nissan', 'Frontier', 2017, 261, 6, 'MANUAL', 'Pickup', 32340],
]

columns = [
    'Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders',
    'Transmission Type', 'Vehicle_Style', 'MSRP'
]

# %%
df = pd.DataFrame(data, columns=columns) # turn data into a dataframe
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
# we can alterantively use a list of dictionaries to create a 
# dataframe

data = [
    {
        "Make": "Nissan",
        "Model": "Stanza",
        "Year": 1991,
        "Engine HP": 138.0,
        "Engine Cylinders": 4,
        "Transmission Type": "MANUAL",
        "Vehicle_Style": "sedan",
        "MSRP": 2000
    },
    {
        "Make": "Hyundai",
        "Model": "Sonata",
        "Year": 2017,
        "Engine HP": None,
        "Engine Cylinders": 4,
        "Transmission Type": "AUTOMATIC",
        "Vehicle_Style": "Sedan",
        "MSRP": 27150
    },
    {
        "Make": "Lotus",
        "Model": "Elise",
        "Year": 2010,
        "Engine HP": 218.0,
        "Engine Cylinders": 4,
        "Transmission Type": "MANUAL",
        "Vehicle_Style": "convertible",
        "MSRP": 54990
    },
    {
        "Make": "GMC",
        "Model": "Acadia",
        "Year": 2017,
        "Engine HP": 194.0,
        "Engine Cylinders": 4,
        "Transmission Type": "AUTOMATIC",
        "Vehicle_Style": "4dr SUV",
        "MSRP": 34450
    },
    {
        "Make": "Nissan",
        "Model": "Frontier",
        "Year": 2017,
        "Engine HP": 261.0,
        "Engine Cylinders": 6,
        "Transmission Type": "MANUAL",
        "Vehicle_Style": "Pickup",
        "MSRP": 32340
    }
]

# %%
df = pd.DataFrame(data)
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df.head() # this gets the first 5 rows
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df.head(n=2) # this gets the first 2 rows
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan  Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150

# %%
df.tail(n=2) # this gets the last 2 rows
# Out:
#      Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 3     GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4  Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 3       4dr SUV  34450
# 4        Pickup  32340

# %% [markdown]
# ## Series
#
# Every column of the pandas DataFrame is a series

# %%
df.Make # you can't do this for column names where spaces are present
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %%
df['Engine Cylinders']
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    6
# Name: Engine Cylinders, dtype: int64

# %%
df[['Engine Cylinders']]
# Out:
#    Engine Cylinders
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 6

# %%
df[["Make", "Model", "Year"]] # accessing multiple series
# Out:
#       Make     Model  Year
# 0   Nissan    Stanza  1991
# 1  Hyundai    Sonata  2017
# 2    Lotus     Elise  2010
# 3      GMC    Acadia  2017
# 4   Nissan  Frontier  2017

# %%
# we can add a new column id

df["id"] = [1, 2, 3, 4, 5]

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP  id
# 0         sedan   2000   1
# 1         Sedan  27150   2
# 2   convertible  54990   3
# 3       4dr SUV  34450   4
# 4        Pickup  32340   5

# %%
del df['id'] # to delete a column
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %% [markdown]
# ## Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.Make.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# we can reconfigure the numbering
df.index = ["a", "b", "c", "d", "e"]
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a   Nissan    Stanza  1991      138.0                 4            MANUAL
# b  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus     Elise  2010      218.0                 4            MANUAL
# d      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# e   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         Sedan  27150
# c   convertible  54990
# d       4dr SUV  34450
# e        Pickup  32340

# %% [markdown]
# ## Accessing Elements

# %%
df.loc[[1]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.loc[[1]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1332, in _LocIndexer._getitem_axis(self, key, axis)
#    1329     if hasattr(key, "ndim") and key.ndim > 1:
#    1330         raise ValueError("Cannot index with multidimensional key")
# -> 1332     return self._getitem_iterable(key, axis=axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1272, in _LocIndexer._getitem_iterable(self, key, axis)
# ...

# %%
df.loc[['a']]
# Out:
#      Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a  Nissan  Stanza  1991      138.0                 4            MANUAL
#
#   Vehicle_Style  MSRP
# a         sedan  2000

# %%
df.loc[[1]] 
# helps locate a particular row before 
# the index was configured to a, b, c, etc

# %%
df.loc[[1, 3, 4]] # helps locate multiple rows

# %%
# helps to locate rows using index while loc does it with 
# the literal number or values
# (in the case where index was "a", "b", etc)
df.iloc[[1, 2, 4]]
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# b  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus     Elise  2010      218.0                 4            MANUAL
# e   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# b         Sedan  27150
# c   convertible  54990
# e        Pickup  32340

# %%
df = df.reset_index() # resets the numbering
# resetting without the drop parameter, df.reset_index(),
# pandas will reset the index back to what it was and add an 'index'
# column as part of the dataframe
df
# Out:
#   index     Make     Model  Year  Engine HP  Engine Cylinders  \
# 0     a   Nissan    Stanza  1991      138.0                 4
# 1     b  Hyundai    Sonata  2017        NaN                 4
# 2     c    Lotus     Elise  2010      218.0                 4
# 3     d      GMC    Acadia  2017      194.0                 4
# 4     e   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 0            MANUAL         sedan   2000
# 1         AUTOMATIC         Sedan  27150
# 2            MANUAL   convertible  54990
# 3         AUTOMATIC       4dr SUV  34450
# 4            MANUAL        Pickup  32340

# %%
df = df.reset_index(drop=True) # completely resets the numbering

df
# Out:
#   index     Make     Model  Year  Engine HP  Engine Cylinders  \
# 0     a   Nissan    Stanza  1991      138.0                 4
# 1     b  Hyundai    Sonata  2017        NaN                 4
# 2     c    Lotus     Elise  2010      218.0                 4
# 3     d      GMC    Acadia  2017      194.0                 4
# 4     e   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 0            MANUAL         sedan   2000
# 1         AUTOMATIC         Sedan  27150
# 2            MANUAL   convertible  54990
# 3         AUTOMATIC       4dr SUV  34450
# 4            MANUAL        Pickup  32340

# %% [markdown]
# ## Element-Wise Operations

# %%
# df['Engine HP'] * 2
# or
df[['Engine HP']] * 2
# Out:
#    Engine HP
# 0      276.0
# 1        NaN
# 2      436.0
# 3      388.0
# 4      522.0

# %%
df[['Engine HP']] / 100
# Out:
#    Engine HP
# 0       1.38
# 1        NaN
# 2       2.18
# 3       1.94
# 4       2.61

# %%
df[['Year']] >= 2015
# Out:
#     Year
# 0  False
# 1   True
# 2  False
# 3   True
# 4   True

# %% [markdown]
# ## Filtering

# %%
df[
    df['Year'] >= 2015 # returns only data that is true
]
# Out:
#   index     Make     Model  Year  Engine HP  Engine Cylinders  \
# 1     b  Hyundai    Sonata  2017        NaN                 4
# 3     d      GMC    Acadia  2017      194.0                 4
# 4     e   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 1         AUTOMATIC         Sedan  27150
# 3         AUTOMATIC       4dr SUV  34450
# 4            MANUAL        Pickup  32340

# %%
df[
    df['Make'] == 'Nissan'
]
# Out:
#   index    Make     Model  Year  Engine HP  Engine Cylinders  \
# 0     a  Nissan    Stanza  1991      138.0                 4
# 4     e  Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 0            MANUAL         sedan   2000
# 4            MANUAL        Pickup  32340

# %%
df[
    (df['Make'] == 'Nissan') & (df['Year'] >= 2015)
]

# & is used here instead of and
# Out:
#   index    Make     Model  Year  Engine HP  Engine Cylinders  \
# 4     e  Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 4            MANUAL        Pickup  32340

# %% [markdown]
# ## String Operations

# %%
'Going to school is so much fun'.replace(" ", "-")
# Out:
# 'Going-to-school-is-so-much-fun'

# %%
# turn all the vehicle style column to all lower case letters
df['Vehicle_Style'].str.lower()
# Out:
# 0          sedan
# 1          sedan
# 2    convertible
# 3        4dr suv
# 4         pickup
# Name: Vehicle_Style, dtype: object

# %%
# to make the changes above show in the dataframe:
df['Vehicle_Style'] = df['Vehicle_Style'].replace(' ', '-').str.lower()
df
# Out:
#   index     Make     Model  Year  Engine HP  Engine Cylinders  \
# 0     a   Nissan    Stanza  1991      138.0                 4
# 1     b  Hyundai    Sonata  2017        NaN                 4
# 2     c    Lotus     Elise  2010      218.0                 4
# 3     d      GMC    Acadia  2017      194.0                 4
# 4     e   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 0            MANUAL         sedan   2000
# 1         AUTOMATIC         sedan  27150
# 2            MANUAL   convertible  54990
# 3         AUTOMATIC       4dr suv  34450
# 4            MANUAL        pickup  32340

# %% [markdown]
# ## Summarizing Operations

# %%
df.MSRP.max()
# Out:
# 54990

# %%
df.MSRP.min()
# Out:
# 2000

# %%
df.MSRP.mean()
# Out:
# 30186.0

# %%
df.MSRP.describe()
# Out:
# count        5.000000
# mean     30186.000000
# std      18985.044904
# min       2000.000000
# 25%      27150.000000
# 50%      32340.000000
# 75%      34450.000000
# max      54990.000000
# Name: MSRP, dtype: float64

# %%
df.describe() # works only with numerical columns
# Out:
#               Year  Engine HP  Engine Cylinders          MSRP
# count     5.000000    4.00000          5.000000      5.000000
# mean   2010.400000  202.75000          4.400000  30186.000000
# std      11.260551   51.29896          0.894427  18985.044904
# min    1991.000000  138.00000          4.000000   2000.000000
# 25%    2010.000000  180.00000          4.000000  27150.000000
# 50%    2017.000000  206.00000          4.000000  32340.000000
# 75%    2017.000000  228.75000          4.000000  34450.000000
# max    2017.000000  261.00000          6.000000  54990.000000

# %%
# summarize the dataframe and round it off to 2 decimal places
df.describe().round(2)
# Out:
#           Year  Engine HP  Engine Cylinders      MSRP
# count     5.00       4.00              5.00      5.00
# mean   2010.40     202.75              4.40  30186.00
# std      11.26      51.30              0.89  18985.04
# min    1991.00     138.00              4.00   2000.00
# 25%    2010.00     180.00              4.00  27150.00
# 50%    2017.00     206.00              4.00  32340.00
# 75%    2017.00     228.75              4.00  34450.00
# max    2017.00     261.00              6.00  54990.00

# %%
df.nunique()
# Out:
# index                5
# Make                 4
# Model                5
# Year                 3
# Engine HP            4
# Engine Cylinders     2
# Transmission Type    2
# Vehicle_Style        4
# MSRP                 5
# dtype: int64

# %%
df.Make.nunique()
# Out:
# 4

# %% [markdown]
# ## Missing Values

# %%
df.isnull()
# Out:
#    index   Make  Model   Year  Engine HP  Engine Cylinders  Transmission Type  \
# 0  False  False  False  False      False             False              False
# 1  False  False  False  False       True             False              False
# 2  False  False  False  False      False             False              False
# 3  False  False  False  False      False             False              False
# 4  False  False  False  False      False             False              False
#
#    Vehicle_Style   MSRP
# 0          False  False
# 1          False  False
# 2          False  False
# 3          False  False
# 4          False  False

# %%
df.isnull().sum() # gives us the total missing values in the dataframe
# Out:
# index                0
# Make                 0
# Model                0
# Year                 0
# Engine HP            1
# Engine Cylinders     0
# Transmission Type    0
# Vehicle_Style        0
# MSRP                 0
# dtype: int64

# %% [markdown]
# ## Grouping
#
# ```
# SELECT
#     tansmission_type,
#     AVG(MSRP)
# FROM
#     cars
# GROUP BY
#     transmission_type
# ```

# %%
df.groupby("Transmission Type").MSRP.max()
# Out:
# Transmission Type
# AUTOMATIC    34450
# MANUAL       54990
# Name: MSRP, dtype: int64

# %%
df.groupby("Transmission Type").MSRP.mean()
# Out:
# Transmission Type
# AUTOMATIC    30800.000000
# MANUAL       29776.666667
# Name: MSRP, dtype: float64

# %% [markdown]
# ## Getting the Numpy Arrays

# %%
df.MSRP.values
# Out:
# array([ 2000, 27150, 54990, 34450, 32340], dtype=int64)

# %%
df.to_dict
# Out:
# <bound method DataFrame.to_dict of   index     Make     Model  Year  Engine HP  Engine Cylinders  \
# 0     a   Nissan    Stanza  1991      138.0                 4
# 1     b  Hyundai    Sonata  2017        NaN                 4
# 2     c    Lotus     Elise  2010      218.0                 4
# 3     d      GMC    Acadia  2017      194.0                 4
# 4     e   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 0            MANUAL         sedan   2000
# 1         AUTOMATIC         sedan  27150
# 2            MANUAL   convertible  54990
# 3         AUTOMATIC       4dr suv  34450
# 4            MANUAL        pickup  32340  >

# %%
# much better
df.to_dict(orient='records')
# Out:
# [{'index': 'a',
#   'Make': 'Nissan',
#   'Model': 'Stanza',
#   'Year': 1991,
#   'Engine HP': 138.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'sedan',
#   'MSRP': 2000},
#  {'index': 'b',
#   'Make': 'Hyundai',
#   'Model': 'Sonata',
#   'Year': 2017,
#   'Engine HP': nan,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle_Style': 'sedan',
#   'MSRP': 27150},
#  {'index': 'c',
#   'Make': 'Lotus',
#   'Model': 'Elise',
#   'Year': 2010,
#   'Engine HP': 218.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'convertible',
#   'MSRP': 54990},
#  {'index': 'd',
#   'Make': 'GMC',
#   'Model': 'Acadia',
#   'Year': 2017,
#   'Engine HP': 194.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle_Style': '4dr suv',
#   'MSRP': 34450},
#  {'index': 'e',
#   'Make': 'Nissan',
#   'Model': 'Frontier',
#   'Year': 2017,
#   'Engine HP': 261.0,
# ...
